# %% [markdown]
# <h1 align="center"> Visualização de Dados com Python</h1

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <div style="flex: 1;">
#         <table>
#             <thead>
#                 <tr>
#                     <th><strong>Termo [em inglês]</strong></th>
#                     <th><strong>Tradução</strong></th>
#                     <th><strong>Observações</strong></th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr>
#                     <td>Chart</td>
#                     <td>Gráfico</td>
#                     <td>Geralmente é acompanhado do tipo do gráfico. <br>Ex: Pie Chart (Pizza), Bar Chart (Barras), Line Chart (Linhas), Bubble Chart (Bolhas), etc.<br></td>
#                 </tr>
#                 <tr>
#                     <td>Plot</td>
#                     <td>Plotagem</td>
#                     <td>Produção de uma imagem por meio de desenhos e linhas. Ação de construir o gráfico.</td>
#                 </tr>
#                 <tr>
#                     <td>Axis / Axes</td>
#                     <td>Eixo</td>
#                     <td>Eixo dos gráficos. <br>Ideia análoga à Matemática, na qual temos X e Y para o caso 2D e X, Y, Z para o caso 3D.<br></td>
#                 </tr>
#                 <tr>
#                     <td>Label</td>
#                     <td>Rótulo</td>
#                     <td>São os rótulos que dão o nome e acompanham cada eixo. <br>Geralmente aparecem acompanhados do respectivo eixo. Ex: <code>x_label</code>, <code>y_label</code>, etc.<br></td>
#                 </tr>
#                 <tr>
#                     <td>Grid</td>
#                     <td>Grade/Malha</td>
#                     <td>É a estrutura de fundo de um gráfico. <br>Linhas horizontais e verticais espaçadas que servem de referência para as unidades dos eixos.<br></td>
#                 </tr>
#                 <tr>
#                     <td>Legend</td>
#                     <td>Legenda</td>
#                     <td>Caixa de texto descritivo, contendo informações sobre os elementos do gráfico. <br>Geralmente traz informação sobre o que significa determinada cor ou traçado e/ou quais as variáveis sendo plotadas.<br></td>
#                 </tr>
#             </tbody>
#         </table>
#     </div>
#     <div style="flex: 1; text-align: center;">
#         <img src="https://www.alura.com.br/artigos/assets/data-visualization-conhecendo-bibliotecas-python/img2_anatomia_de_uma_figura_matplotlib.jpeg" width="90%">
#     </div>
# </div>

# %% [markdown]
# *Referências 📚*
# 1. https://matplotlib.org/stable/plot_types/
# 2. https://matplotlib.org/stable/gallery/
# 3. https://seaborn.pydata.org/examples/index.html
# 4. https://www.alura.com.br/artigos/o-que-e-um-histograma
# 5. https://www.alura.com.br/artigos/o-que-e-um-histograma

# %% [markdown]
# Estudo de caso:
# > Ao longo das aulas, vamos desenvolver um projeto para que essa empresa possa otimizar esses serviços de aconselhamento e consultoria para essas pessoas que desejam fazer imigração.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imigrantes_canada.csv')
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %% [markdown]
# <h2 align="center">Análise de tendências de migração do Brasil em um determinado período </h2>

# %%
# Tornar o index do dataframe como o país
df.set_index('País', inplace=True)
df.head(10)
# Out:
#                                   Continente                     Região  1980  \
# País
# Afeganistão                             Ásia                Sul da Ásia    16
# Albânia                               Europa              Sul da Europa     1
# Argélia                               África            Norte da África    80
# Samoa Americana                      Oceânia                  Polinésia     0
# Andorra                               Europa              Sul da Europa     0
# Angola                                África               África média     1
# Antígua e Barbuda  América Latina e o Caribe                     Caribe     0
# Argentina          América Latina e o Caribe             América do Sul   368
# Armênia                                 Ásia             Ásia Ocidental     0
# Austrália                            Oceânia  Austrália e Nova Zelândia   702
#
#                    1981  1982  1983  1984  1985  1986  1987  ...  2005  2006  \
# ...

# %%
# Armarzenar o intervalo de tempo
anos: list[str] = list(map(str, range(1980,2014)))
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
# Ano x Nº de Imigrantes
brasil = df.loc['Brasil', anos]
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
brasil_dict = {
    'ano' : brasil.index.tolist(),
    'imigrantes' : brasil.values.tolist()
}
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) 
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.title("Imigração do Brasil para o Canadá")
# Rótulos
plt.xlabel('Ano')
plt.ylabel('Número de Imigrantes')
plt.show()

# %%
# Desafio: criar um gráfico de linhas comparando os números de imigrantes do Brasil e Argentina para o Canadá
plt.figure(figsize=(8,4))
plt.plot(df.loc['Argentina', anos].index.tolist() , df.loc['Argentina', anos].values.tolist(), label='Argentina')
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'], label='Brasil')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.title("Comparação de Imigração: Brasil e Argentina para o Canadá")
# Rótulos
plt.xlabel('Ano')
plt.ylabel('Número de Imigrantes')
plt.legend()
plt.show()

# %% [markdown]
# <h3>Trabalhando com Figuras em Matplotlib - (Abordagem Orientada a Objetos) </h3>

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.set_title("Imigração do Brasil para o Canadá\n1980-2013")
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], label='Brasil')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # Frequência de 5 em 5 no eixo x
ax.set_xlabel('Ano')
ax.set_ylabel('Nº de Imigrantes')
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(
    nrows=1,
    ncols=2,
    figsize=(15,5)
)
axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá\n1980-2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('N° de Imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))


axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Boxplot da Imigração do Brasil para o Canadá\n1980-2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('N° de Imigrantes')
# Out:
# Text(0, 0.5, 'N° de Imigrantes')

# %%
fig, axs = plt.subplots(
    nrows=2, 
    ncols=2,
    figsize = (10, 6)
)
fig.subplots_adjust(hspace=0.5, wspace=0.3)

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')


axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
    ax.set_xlabel('Ano')
    ax.set_ylabel('Nº de Imigrantes')

plt.show()

# %% [markdown]
# Do jeito que tá os gráficos, o valor de y não tá na mesma escala o que faz com que pareça que Brasil e Colômbia tão próximos um do outro.

# %%
fig, axs = plt.subplots(
    nrows=2, 
    ncols=2,
    figsize = (10, 6)
)
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle("Imigração dos 4 maiores países da América do Sul para o Canadá\n1980-2013")

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')


axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
    ax.set_xlabel('Ano')
    ax.set_ylabel('Nº de Imigrantes')

ymin, ymax = 0, 7_000

for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)

plt.show()

# %% [markdown]
# ### Desafio

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}
df_lojas = pd.DataFrame(vendas_2022, index=lojas)
df_lojas = df_lojas.T

# %%
df_lojas['A'].values
# Out:
# array([100, 120, 150, 180, 220, 230, 250, 260, 240, 220, 400, 300],
#       dtype=int64)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))
fig.suptitle("Comparação de vendas entre lojas A, B, C e D")
# fig.subplots_adjust(hspace=0.5, wspace=0.3)

ax[0,0].plot(df_lojas.index.tolist(), df_lojas['A'].values)
ax[0,0].set_title("Vendas loja A")

ax[0,1].plot(df_lojas.index.tolist(), df_lojas['B'].values)
ax[0,1].set_title("Vendas loja B")

ax[1,0].plot(df_lojas.index.tolist(), df_lojas['C'].values)
ax[1,0].set_title("Vendas loja C")

ax[1,1].plot(df_lojas.index.tolist(), df_lojas['D'].values)
ax[1,1].set_title("Vendas loja D")

# Rótulos 
for ax in axs.flat:
    ax.set_xlabel("Mês")
    ax.set_ylabel("Número de Vendas")



plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Customizando com Matplotlib</h2>

# %%
# Figure
fig, ax = plt.subplots(figsize=(8,4))
ax.set_title("Imigração do Brasil para o Canadá\n1980-2013", fontsize=18, loc='left')

# Ticks
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # Frequência de 5 em 5 no eixo x
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Labels
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Nº de Imigrantes',fontsize=14)
# Plot
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], label='Brasil', lw=3)
plt.grid(linestyle='--')
plt.show()

# %%
# Explorando estilos:
matplotlib_themes = ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', 
                     '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background',
                       'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8',
                         'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark',
                           'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep',
                             'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel',
                               'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 
                               'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

for tema in matplotlib_themes:
    with plt.style.context(tema):
        fig, ax = plt.subplots(figsize=(8, 4))
        ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3)
        ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=20, loc='left')
        ax.set_ylabel('Número de imigrantes', fontsize=14)
        ax.set_xlabel('Ano', fontsize=14)
        ax.yaxis.set_tick_params(labelsize=12)
        ax.xaxis.set_tick_params(labelsize=12)
        ax.xaxis.set_major_locator(plt.MultipleLocator(5))
        plt.show()

# %%
america_do_sul = df.query('Região == "América do Sul"')
america_do_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
fig, ax = plt.subplots(figsize=(12,5))
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']
ax.barh(america_do_sul.index, america_do_sul['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980-2013', fontsize=18)
ax.set_xlabel("Nº de Imigrantes", fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
america_sul_sorted = america_do_sul.sort_values('Total', ascending=True) # Maior pro menor
fig, ax = plt.subplots(figsize=(12,6))

cores = ['green'  if pais == 'Brasil' else 'silver' for pais in america_sul_sorted.index]

ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do Sul: Brasil foi o quarto país com mais imigrante para o Canadá\n1980-2013', fontsize=18, loc='left')
ax.set_xlabel("Nº de Imigrantes", fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Valores maximo de cada barra 
for i, v in enumerate(america_sul_sorted['Total']):
    ax.text(x=v+20, y=i, s=str(v), color='black', fontsize=12, ha='left', va='center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)
plt.show()

# %% [markdown]
# [Cores no Matplotlib](https://matplotlib.org/stable/gallery/color/named_colors.html)

# %%
# Figure
fig, ax = plt.subplots(figsize=(8,4))
ax.set_title("Imigração do Brasil para o Canadá\n1980-2013", fontsize=18, loc='left')

# Ticks
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # Frequência de 5 em 5 no eixo x
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Labels
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Nº de Imigrantes',fontsize=14)
# Plot
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], label='Brasil', lw=3)
plt.grid(linestyle='--')
# Remover frame
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.savefig('imigracao_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# - Desafio

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))
fig.suptitle("Comparação de vendas entre lojas A, B, C e D", fontsize=18)

# fig.subplots_adjust(hspace=0.5, wspace=0.3)

ax[0,0].plot(df_lojas.index.tolist(), df_lojas['A'].values, color='blue',lw=3)
ax[0,0].set_title("Loja A", fontsize=16)

ax[0,1].plot(df_lojas.index.tolist(), df_lojas['B'].values, color='green',lw=3)
ax[0,1].set_title("Loja B", fontsize=16)


ax[1,0].plot(df_lojas.index.tolist(), df_lojas['C'].values,'red',lw=3)
ax[1,0].set_title("Loja C", fontsize=16)


ax[1,1].plot(df_lojas.index.tolist(), df_lojas['D'].values, 'cyan',lw=3)
ax[1,1].set_title("Loja D", fontsize=16)


# Rótulos 
for ax in axs.flat:
    ax.set_xlabel("Mês")
    ax.set_ylabel("Número de Vendas")
    ax.grid(color='lightgrey')
    

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Conhecendo a Biblioteca Seaborn </h2>

# %% [markdown]
# ### Top 10 países

# %%
import seaborn as sns

# %%
top10 = df.sort_values(by='Total', ascending=False).head(10) # 10 primeiros paises
top10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
# No eixo y, coloca apenas o nome total pois em data já foi passado qual o DataFrame
sns.barplot(data=top10, x=top10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
ax = sns.barplot(data=top10, y=top10.index, x='Total',orient='y')
ax.set(title='Países com maior taxa de imigração para o Canadá\n1980-2013',
       xlabel='Nº de Imigrantes',
       ylabel='')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top10, y=top10.index, x='Total')
ax.set_title('Países com maior taxa de imigração para o Canadá\n1980-2013',loc='left', fontsize=16)
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html : Paletas de cores do Seaborn

# %%
def gerar_grafico_paleta(paleta):
    fig, ax = plt.subplots(figsize=(8,4))
    ax = sns.barplot(data=top10, y=top10.index, x='Total', orient='h', hue='Total', palette=paleta, legend=False)
    ax.set_title('Países com maior taxa de imigração para o Canadá\n1980-2013',loc='left', fontsize=16)
    ax.set_xlabel('Nº de imigrantes', fontsize=14)
    ax.set_ylabel('', fontsize=14)
    ax.grid(color='silver', linestyle='--')    
    sns.despine()
    plt.show()

# %%
sns.set_theme(style='dark')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('tab10')

# %% [markdown]
# - Desafio
# Nesta etapa, seu desafio é criar uma figura contendo as tendências de imigração dos 4 maiores países da América latina: Brasil, Argentina, Peru e Colômbia. Através dessa criação você pode explorar diversas possibilidades e reconhecer de forma atrativa o seu processo de desenvolvimento.E não nos esqueçamos das orientações! Essa figura precisa ter uma linha para cada país, título, rótulos nos eixos, cores apropriadas, um tema da biblioteca Seaborn e legenda. Por isso, pense nas questões de acessibilidade, como tamanho das fontes e espessura das linhas.

# %%
sns.set_theme()
sns.set_palette('Dark2')

fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(df.loc['Brasil', anos], label='Brasil', lw=3)
ax = sns.lineplot(df.loc['Argentina', anos], label='Argentina', lw=3)
ax = sns.lineplot(df.loc['Peru', anos], label='Peru', lw=3)
ax = sns.lineplot(df.loc['Colômbia', anos], label='Colômbia', lw=3)

ax.set_title('Imigração dos maiores países da América do Sul\npara o Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))

plt.show()
